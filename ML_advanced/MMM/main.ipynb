# %% [markdown]
# Marketing Mix Modeling

# %% [markdown]
# Explore the dynamics of advertising impact on product sales with this synthesized dataset. Created using Python programming language, the dataset comprises seven columns representing advertising costs on various platforms — TV, Billboards, Google Ads, Social Media, Influencer Marketing, and Affiliate Marketing. The last column, 'Product_Sold' quantifies the corresponding number of units sold. This dataset is designed for analysis and experimentation, allowing you to delve into the relationships between different advertising channels and the resulting product sales. Gain insights into marketing strategies and optimize your approach using this comprehensive, yet user-friendly dataset.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("MMM_data(Sheet1).csv", sep=";", )
df
# Out:
#                 TV Manufacturing Brand        DATE  DEMAND   \
# 0     TV Manufacturing & Supplier Unit  01/01/2010     4384
# 1     TV Manufacturing & Supplier Unit  02/01/2010     4366
# 2     TV Manufacturing & Supplier Unit  03/01/2010     4006
# 3     TV Manufacturing & Supplier Unit  04/01/2010     4076
# 4     TV Manufacturing & Supplier Unit  05/01/2010     4834
# ...                                ...         ...      ...
# 2608  TV Manufacturing & Supplier Unit  21/02/2017     7312
# 2609  TV Manufacturing & Supplier Unit  22/02/2017     6456
# 2610  TV Manufacturing & Supplier Unit  23/02/2017     6060
# 2611  TV Manufacturing & Supplier Unit  24/02/2017     5980
# 2612  TV Manufacturing & Supplier Unit  25/02/2017     5609
#
#      Consumer Price Index (CPI) Consumer Confidence Index(CCI)  \
# 0                         104,9                           96,3
# 1                         104,9                           96,3
# 2                         104,9                           96,3
# 3                         104,9                           96,3
# 4                         104,9                           96,3
# ...                         ...                            ...
# 2608                      101,4                          100,3
# 2609                      101,4                          100,3
# 2610                      101,4                          100,3
# 2611                      101,4                          100,3
# 2612                      101,4                          100,3
#
#      Producer Price Index (PPI) Unit Price ($)  POS/ Supply Data   SALES ($)  \
# 0                         106,7         361,62              4240   1533268,8
# 1                         106,7         361,62              4266  1542670,92
# 2                         106,7         361,62              4206  1520973,72
# 3                         106,7         361,62              4176  1510125,12
# 4                         106,7         361,62              5234  1892719,08
# ...                         ...            ...               ...         ...
# 2608                      103,3         361,62              6974  2521937,88
# 2609                      103,3         361,62              6123  2214199,26
# 2610                      103,3         361,62              5989  2165742,18
# 2611                      103,3         361,62              5877  2125240,74
# 2612                      103,3         361,62              5467  1976976,54
#
#      Advertising Expenses (SMS) Advertising Expenses(Newspaper ads)  \
# 0                       77,4819                           14,104193
# 1                       73,4783                           13,298758
# 2                       80,6093                           13,200691
# 3                       65,9319                           12,721429
# 4                       77,4819                           14,104193
# ...                         ...                                 ...
# 2608                    60,6667                           13,488857
# 2609                    59,1026                           13,206593
# 2610                    61,1351                           12,775135
# 2611                    53,7865                           12,940132
# 2612                    71,5344                           13,742857
#
#      Advertising Expenses(Radio) Advertising Expenses(TV)  \
# 0                        112,337                1479,4565
# 1                       105,7133                1369,8913
# 2                       108,7702                1428,0645
# 3                        93,3065                1309,3548
# 4                        112,337                1479,4565
# ...                          ...                      ...
# 2608                      76,725                1399,6615
# 2609                     78,6058                1369,3491
# 2610                     76,2872                1341,7297
# 2611                     74,9424                1323,5526
# 2612                     90,9226                1448,9683
#
#      Advertising Expenses(Internet) GRP (NewPaper ads) GRP(SMS) GRP(Radio  \
# 0                           722,571             95,333  11,8398        91
# 1                           717,857            114,957  27,8039  111,9091
# 2                           653,333             113,09        0   94,6364
# 3                           622,095             72,442        0   98,5909
# 4                           722,571             95,333  11,8398        91
# ...                             ...                ...      ...       ...
# 2608                       4168,952            272,036        0   93,9545
# 2609                       3984,429            817,581  31,3919   81,9091
# 2610                       3943,524           1288,844  31,1817   98,6818
# 2611                           5732            540,757  31,5487  111,0455
# 2612                       4794,048           1244,833  31,3605   93,0455
#
#      GRP(Internet)   GRP(TV)
# 0         276,3636  756,5909
# 1         291,3182  860,1364
# 2         282,7273  751,9545
# 3         306,3182  749,4545
# 4         276,3636  756,5909
# ...            ...       ...
# 2608      222,7727  805,9091
# 2609      225,1818  816,2727
# 2610      224,5455  855,8636
# 2611      232,8636  791,3636
# 2612           200  889,3636
#
# [2613 rows x 19 columns]

# %%
df.info(df.columns[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2613 entries, 0 to 2612
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   TV Manufacturing Brand               2613 non-null   object
#  1   DATE                                 2613 non-null   object
#  2   DEMAND                               2613 non-null   int64
#  3   Consumer Price Index (CPI)           2613 non-null   object
#  4   Consumer Confidence Index(CCI)       2613 non-null   object
#  5   Producer Price Index (PPI)           2613 non-null   object
#  6   Unit Price ($)                       2613 non-null   object
#  7   POS/ Supply Data                     2613 non-null   int64
#  8   SALES ($)                            2613 non-null   object
#  9   Advertising Expenses (SMS)           2613 non-null   object
#  10  Advertising Expenses(Newspaper ads)  2613 non-null   object
#  11  Advertising Expenses(Radio)          2613 non-null   object
#  12  Advertising Expenses(TV)             2613 non-null   object
#  13  Advertising Expenses(Internet)       2613 non-null   object
#  14  GRP (NewPaper ads)                   2613 non-null   object
#  15  GRP(SMS)                             2613 non-null   object
#  16  GRP(Radio                            2613 non-null   object
#  17  GRP(Internet)                        2613 non-null   object
#  18  GRP(TV)                              2613 non-null   object
# dtypes: int64(2), object(17)
# memory usage: 388.0+ KB
